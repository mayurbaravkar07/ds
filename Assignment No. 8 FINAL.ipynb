# %% [markdown]
# 8) Data Visualization I
# 1. Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information about
# the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to see if we
# can find any patterns in the data.
# 2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger
# is distributed by plotting a histogram.

# %%
import pandas as pd

# %%
df=pd.read_csv("Titanic.csv")

# %%
df
# Out:
#         sex   age  sibsp  parch     fare embarked   class    who  alone  \
# 0      male  22.0      1      0   7.2500        S   Third    man  False
# 1    female  38.0      1      0  71.2833        C   First  woman  False
# 2    female  26.0      0      0   7.9250        S   Third  woman   True
# 3    female  35.0      1      0  53.1000        S   First  woman  False
# 4      male  35.0      0      0   8.0500        S   Third    man   True
# ..      ...   ...    ...    ...      ...      ...     ...    ...    ...
# 886    male  27.0      0      0  13.0000        S  Second    man   True
# 887  female  19.0      0      0  30.0000        S   First  woman   True
# 888  female   NaN      1      2  23.4500        S   Third  woman  False
# 889    male  26.0      0      0  30.0000        C   First    man   True
# 890    male  32.0      0      0   7.7500        Q   Third    man   True
#
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['fare'])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['age'],df['fare'])

# %%
sns.distplot(df['fare'])
# Out:
# /home/vishakha/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.boxplot(df['fare'])
# Out:
# /home/vishakha/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fare'>

# %%
sns.jointplot(x='age', y='fare', data=df)

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/numpy/lib/histograms.py:351, in _unsigned_subtract(a, b)
#     350 try:
# --> 351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 sns.pairplot(df)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
# ...

# %%
sns.pairplot(df, hue='sex')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 sns.pairplot(df, hue='sex')
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:2130, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2128     diag_kws.setdefault("fill", True)
# ...

# %%
sns.rugplot(df['fare'])
# Out:
# <AxesSubplot:xlabel='fare'>

# %%
sns.barplot(x='sex', y='age', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.countplot(x='sex', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='sex', y='age', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x='sex', y='age', data=df, hue="survived")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex', y='age', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='sex', y='age', data=df)
# Out:
# /home/vishakha/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 5.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='sex', y='age', data=df, hue='survived')
# Out:
# /home/vishakha/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 5.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='sex', y='age', data=df, hue='survived', split=True)
# Out:
# /home/vishakha/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# /home/vishakha/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 21.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/vishakha/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.catplot(x='sex', y='age', data=df, hue='survived', split=True)
# Out:
# /home/vishakha/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.dogplot(x='sex', y='age', data=df, hue='survived', split=True)

# %%
sns.pointplot(x='sex', y='age', data=df, hue='survived', split=True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>
